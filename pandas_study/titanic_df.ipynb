# %%
import pandas as pd

# %%
df_titanic=pd.read_csv('titanic_practice.csv')

# %%
df_titanic.to_csv('titanic_practice.csv',index=False)

# %%
df_titanic
# Out:
#      Survived  Pclass  Gender   Age     Fare
# 0           0   Third    male  22.0   7.2500
# 1           1   First  female  38.0  71.2833
# 2           1   Third  female  26.0   7.9250
# 3           1   First  female  35.0  53.1000
# 4           0   Third    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0  Second    male  27.0  13.0000
# 887         1   First  female  19.0  30.0000
# 888         0   Third  female   NaN  23.4500
# 889         1   First    male  26.0  30.0000
# 890         0   Third    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
df_titanic['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df_titanic
# Out:
#      Survived  Pclass  Gender   Age     Fare
# 0           0   Third    male  22.0   7.2500
# 1           1   First  female  38.0  71.2833
# 2           1   Third  female  26.0   7.9250
# 3           1   First  female  35.0  53.1000
# 4           0   Third    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0  Second    male  27.0  13.0000
# 887         1   First  female  19.0  30.0000
# 888         0   Third  female   NaN  23.4500
# 889         1   First    male  26.0  30.0000
# 890         0   Third    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
df_titanic.plot ( kind='scatter', x='Age', y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
df_titanic.columns
# Out:
# Index(['Survived', 'Pclass', 'Gender', 'Age', 'Fare'], dtype='object')

# %%
df_titanic[['Survived','Pclass']]
# Out:
#      Survived  Pclass
# 0           0   Third
# 1           1   First
# 2           1   Third
# 3           1   First
# 4           0   Third
# ..        ...     ...
# 886         0  Second
# 887         1   First
# 888         0   Third
# 889         1   First
# 890         0   Third
#
# [891 rows x 2 columns]

# %%
# 행, 열
df_titanic.loc[0,'Pclass']
# Out:
# 'Third'

# %%
df_titanic.iloc[0]
# Out:
# Survived        0
# Pclass      Third
# Gender       male
# Age          22.0
# Fare         7.25
# Name: 0, dtype: object

# %%
# Drop 연습
data1 = [[95,65],[84,83]]
idx=['A','B']
cols=columns=['국어','영어']
df = pd.DataFrame(data1, index=idx,columns = cols)

# %%
df
# Out:
#    국어  영어
# A  95  65
# B  84  83

# %%
df.drop(['영어'],axis=1)
# Out:
#    국어
# A  95
# B  84

# %%
df.reset_index()
# Out:
#   index  국어  영어
# 0     A  95  65
# 1     B  84  83

# %%
df.reset_index(drop=True)
# Out:
#    국어  영어
# 0  95  65
# 1  84  83

# %%
# 컬럼명 변경하기
df.columns = ['영어','국어']

# %%
df
# Out:
#    영어  국어
# A  95  65
# B  84  83

# %%
df.set_axis([ '국어','영어'],axis=1 )
# Out:
#    국어  영어
# A  95  65
# B  84  83

# %%
df.rename(columns={'국어':'과학'})
# Out:
#    영어  과학
# A  95  65
# B  84  83

# %%
df
# Out:
#    영어  국어
# A  95  65
# B  84  83

# %%
df.rename_axis(None)
# Out:
#    영어  국어
# A  95  65
# B  84  83

# %%
df_multi={ ('국어','남'):{'1반':10,'2반':20},('국어','여'):{'1반':30,'2반':40} }
multi_df=pd.DataFrame(df_multi)

# %%
multi_df
# Out:
#     국어
#      남   여
# 1반  10  30
# 2반  20  40

# %%
multi_df.columns
# Out:
# MultiIndex([('국어', '남'),
#             ('국어', '여')],
#            )

# %%
multi_df.stack()
# Out:
# /var/folders/q1/1v_7c6x10y37rl2147f98sq80000gn/T/ipykernel_71549/1449480516.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   multi_df.stack()
#       국어
# 1반 남  10
#    여  30
# 2반 남  20
#    여  40

# %%
multi_df <90
# Out:
#       국어
#        남     여
# 1반  True  True
# 2반  True  True

# %%
s1=pd.Series([1,5,0,4], index=list('ABCD'))
s2=pd.Series([1,2,3,3], index=list('ABCD'))

# %%
s1,s2
# Out:
# (A    1
#  B    5
#  C    0
#  D    4
#  dtype: int64,
#  A    1
#  B    2
#  C    3
#  D    3
#  dtype: int64)

# %%
s1+s2
# Out:
# A    2
# B    7
# C    3
# D    7
# dtype: int64

# %%
s1.add(s2)
# Out:
# A    2
# B    7
# C    3
# D    7
# dtype: int64

# %%
s1>3
# Out:
# A    False
# B     True
# C    False
# D     True
# dtype: bool

# %%
s2>3
# Out:
# A    False
# B    False
# C    False
# D    False
# dtype: bool

# %%
(s1>3) & (s2>3)
# Out:
# A    False
# B    False
# C    False
# D    False
# dtype: bool

# %%
s1==s2
# Out:
# A     True
# B    False
# C    False
# D    False
# dtype: bool

# %%
s1.eq(s2)
# Out:
# A     True
# B    False
# C    False
# D    False
# dtype: bool

# %%
s1.gt(0) & s1.lt(3)
# Out:
# A     True
# B    False
# C    False
# D    False
# dtype: bool

# %%
s1.mul(s2)
# Out:
# A     1
# B    10
# C     0
# D    12
# dtype: int64

# %%
report = {'성': ['김','강'],'이름':['판다','승주'],'국어':[79,65],'영어':[68,83]}
df_report = pd.DataFrame(report)

# %%
df_report
# Out:
#    성  이름  국어  영어
# 0  김  판다  79  68
# 1  강  승주  65  83

# %%
df_all =df_report['국어']+df_report['영어']

# %%
df_all
# Out:
# 0    147
# 1    148
# dtype: int64

# %%
df_report['국어']>df_report['영어']
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
df_report[['국어','영어']]//3
# Out:
#    국어  영어
# 0  26  22
# 1  21  27

# %%
df_new=df_report.rename(columns={'국어':'과학'} )

# %%
df_new
# Out:
#    성  이름  과학  영어
# 0  김  판다  79  68
# 1  강  승주  65  83

# %%
# 컬럼이 다른 걸 더하면 nan값 
df_new+df_report
# Out:
#    과학  국어   성   영어    이름
# 0 NaN NaN  김김  136  판다판다
# 1 NaN NaN  강강  166  승주승주

# %%
df_report.add(df_new,fill_value=0)
# Out:
#      과학    국어   성   영어    이름
# 0  79.0  79.0  김김  136  판다판다
# 1  65.0  65.0  강강  166  승주승주

# %%
broad =[[1,1],[1,2]]
df_broad=pd.DataFrame(broad,index=list('ab'),columns=list('AB') )
b1 = pd.Series([0,1],index=list('AB'))
b2 = pd.Series([0,1],index=list('ab'))

# %%
df_broad
# Out:
#    A  B
# a  1  1
# b  1  2

# %%
df_broad*b1
# Out:
#    A  B
# a  0  1
# b  0  2

# %%
b1
# Out:
# A    0
# B    1
# dtype: int64

# %%
df_broad.mul(b1,axis=0)
# Out:
#     A   B
# A NaN NaN
# B NaN NaN
# a NaN NaN
# b NaN NaN

# %%
df_stock=pd.read_csv('stock.csv')

# %%
#nbformat 오류 발생
df_stock.div(df_stock.iloc[0]).plot(backend = 'plotly', width = 600 , height=400)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/vsmk/lib/python3.9/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File /opt/anaconda3/envs/vsmk/lib/python3.9/site-packages/plotly/basedatatypes.py:846, in BaseFigure._ipython_display_(self)
#     843 import plotly.io as pio
#     845 if pio.renderers.render_on_display and pio.renderers.default:
# --> 846     pio.show(self)
#     847 else:
#     848     print(repr(self))
#
# File /opt/anaconda3/envs/vsmk/lib/python3.9/site-packages/plotly/io/_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
# ...

# %%
aggre_data = [[10,float('nan')],[20,20]]
df_aggre= pd.DataFrame(aggre_data, index = list('AB'),columns=['국어','영어'])

# %%
df_aggre
# Out:
#    국어    영어
# A  10   NaN
# B  20  20.0

# %%
df_aggre.mean()
# Out:
# 국어    15.0
# 영어    20.0
# dtype: float64

# %%
df_aggre.cumsum()
# Out:
#    국어    영어
# A  10   NaN
# B  30  20.0

# %%
df_aggre.eq(2).any(axis=1)
# Out:
# A    False
# B    False
# dtype: bool

# %%
df_aggre.eq(2).any()
# Out:
# 국어    False
# 영어    False
# dtype: bool
