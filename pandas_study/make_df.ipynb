# %%
import pandas as pd
df = pd.DataFrame( [ [63,93,97],[89,83,71]],
index = ['김판다','강승주'],
columns = ['국어','영어','수학'])
print(df) 

print( df.values , "values" )
print( df.columns ) 

print(df > 90, "????")
df2 = (df > 90)
print(df2)
# Out:
#      국어  영어  수학
# 김판다  63  93  97
# 강승주  89  83  71
# [[63 93 97]
#  [89 83 71]] values
# Index(['국어', '영어', '수학'], dtype='object')
#         국어     영어     수학
# 김판다  False   True   True
# 강승주  False  False  False ????
#         국어     영어     수학
# 김판다  False   True   True
# 강승주  False  False  False
# {'김판다': 63, '강승주': 89}
#      국어
# 김판다  63
# 강승주  89

# %% [markdown]
# # 딕셔너리로 데이터 프레임 생성하기

# %%
df3 ={ '국어':{'김판다': 63,'강승주':89} }
print(df3['국어'])
df3=pd.DataFrame(df3)
print(df3)
# Out:
# {'김판다': 63, '강승주': 89}
#      국어
# 김판다  63
# 강승주  89
